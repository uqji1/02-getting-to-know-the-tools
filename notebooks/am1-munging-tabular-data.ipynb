# %% [markdown]
# # Munging tabular data
#
# We're going to go through how to munge tabular data in more detail (and _slowly_). The aim is for you to get comfortable with the tools we're using:
#
# - [pandas](pandas.pydata.org) for data handling (our dataframe library)
# - [seaborn](seaborn.pydata.org) for _nice_ data visualization
# - [scipy](scipy.org) for scientific libraries (particularly `scipy.stats` which we'll use for fitting some more unusual probability distributions), and
# - [statsmodels](statsmodels.org) which gives us some more expressive curve fitting approaches
#
# The other aim is to get familiar with code-sharing workflows - so we will be doing pair programming for the duration of the day! _You will probably want to take a moment to look at the documentation of the libraries above - especially pandas_
#
# The other useful resource is Stack Overflow - if you have a question that sounds like 'how do I do {x}' then someone will probably have answered it on SO. Questions are also tagged by library so if you have a particular pandas question you can do something like going to https://stackoverflow.com/questions/tagged/pandas (just replace the 'pandas' in the URL with whatever library you're trying to use.
#
# Generally answers on SO are probably a lot closer to getting you up and running than the documentation. Once you get used to the library then the documentation is generally a quicker reference. We will cover strategies for getting help in class.
#
# ## Git links
#
# We will be working through using GitHub and GitKraken to share code between pairs. We will go through all the workflow in detail in class but here are some useful links for reference:
#
# - GitKraken interface basics: https://support.gitkraken.com/start-here/interface
# - Staging and committing (save current state -> local history): https://support.gitkraken.com/working-with-commits/commits
# - Pushing and pulling (sync local history <-> GitHub history): https://support.gitkraken.com/working-with-repositories/pushing-and-pulling
# - Forking and pull requests (request to sync your GitHub history <-> someone else's history - requires a _review_):
#   - https://help.github.com/articles/about-forks/
#   - https://help.github.com/articles/creating-a-pull-request-from-a-fork/
#
# ## Step 1: Reading my data
#
# In pairs work out how to read your data into a pandas dataframe.
#
# If you have your own tabular data please start using it here. If not, use the ATCO dataset from last week.

# %%
import pandas as pd
import os
from os import path

# your code goes here
os.getcwd()
# Out:
# 'C:\\Users\\ji.zhang\\Desktop\\core-skills\\02-getting-to-know-the-tools\\notebooks'

# %%
data_folder = path.join(
    path.abspath('..'),  # '..' means the directory above this one
    'data')
data_folder
# Out:
# 'C:\\Users\\ji.zhang\\Desktop\\core-skills\\02-getting-to-know-the-tools\\data'

# %%
os.listdir(data_folder)
# Out:
# ['data_goes_here.txt', 'Mains Faults Data_SAP_2010-2016.xlsx']

# %% [markdown]
# Once you've worked this out in the Jupyter notebook, transfer your code to a Python script (say a function called `load_data` in a file called `munging.py` in the same directory as the notebooks - you can create a text file in the Jupyter notebook home screen). Then try importing your load function with
#
# ```python
# from munging import load_data
#
# df = load_data('path/to/datafile')
# ```

# %%
# This points to the location of the fault data file on my computer
fault_file = path.join(data_folder, 'Mains Faults Data_SAP_2010-2016.xlsx')

# First we need to see what sheets we have available in the book
faults_xl = pd.ExcelFile(fault_file)
faults_xl.sheet_names
# Out:
# ['Method',
#  'Catalogue Codes Desc',
#  'All Notifications_2010-2016',
#  'Pivot_Leaks_Mains Failure',
#  'Pivot_Leaks_3rd Party',
#  'Pivot_Leaks_Tree Roots',
#  'Pivot_No Gas_Water in Main']

# %%
df = faults_xl.parse('All Notifications_2010-2016')
df.head()
# Out:
#    Notification Notif.date  Notification Year Code group Damage Code  \
# 0     301049381 2011-05-20               2011     MNWORK        CHCK
# 1     301116137 2011-12-01               2011     MNWORK        CHCK
# 2     301630883 2015-08-17               2015   SNSERSTD         NEW
# 3     300943307 2010-06-13               2010     MNWORK        CHCK
# 4     301079516 2011-08-16               2011     MNWORK        CHCK
#
#   Code group.1 Cause code Code group.2 ObjectPartCode Functional Loc.  \
# 0     MNREQUST       CUST     MNOBJECT           PIPE        00900834
# 1     MNREQUST       AGAS     MNOBJECT           PIPE        00895059
# 2          NaN        NaN     MNOBJECT           PIPE        01007110
# 3      MNCAUSE       3PTY     MNOBJECT           PIPE        00876628
# 4     MNREQUST       CUST     MNOBJECT           PIPE        00898718
#
#     ...    Priority Priority Code                             Description.1  \
# 0   ...         NaN            SP                          PIP 89 DRILLSHOT
# 1   ...         NaN            SP  PIP 18 Access Rights Mandurah Gas Latera
# 2   ...         NaN            SN                       9 SLAB INSTALLATION
# 3   ...         NaN            SP                    PIP ****SITE VISIT****
# 4   ...         NaN            SP                        PIP 1016 EXCAVTION
#
#   User status System status         Cause code text        City  \
# 0   INI  NORD     NOCO NOPT        Customer Request       CAPEL
# 1         INI     NOCO ORAS             AGN Request    PINJARRA
# 2         INI          OSNO                     NaN  BASSENDEAN
# 3   INI  NORD     ATCO NOCO  3rd Party Intervention     WANGARA
# 4   INI  NORD     NOCO NOPT        Customer Request     ALKIMOS
#
#   Malfunct. start Malfunct.end Location
# 0      2011-05-20   2011-05-24       BS
# 1      2011-12-01          NaT       MA
# 2      2015-08-17          NaT       NM
# 3      2010-06-07   2010-06-08       NM
# 4      2011-08-17   2011-08-17       NM
#
# [5 rows x 31 columns]

# %% [markdown]
# Next work out how to access a column within your dataframe.
#
# - How can you list all the column names?
# - There are two ways to access columns by name - try to find out what both of these are.
# - There's also methods to access columns by number - try to do this as well
#
# Next look at how to access rows - both using labels and numbers.

# %%
df.columns[0]
# Out:
# 'Notification'

# %%
(df.set_index('Notification'))['Code group'].iloc[4:25]
# Out:
# Notification
# 301079516      MNWORK
# 301660103      MNWORK
# 301403668         NaN
# 301468466      MNWORK
# 301297459    MNDAMAGE
# 301453151    MNDAMAGE
# 301506040    MNDAMAGE
# 301335630    MNDAMAGE
# 301267394    MNDAMAGE
# 301267796    MNDAMAGE
# 300927685    MNDAMAGE
# 301422743    MNDAMAGE
# 301443106    MNDAMAGE
# 301296680    MNDAMAGE
# 300914181    MNDAMAGE
# 300961980    MNDAMAGE
# 300993615    MNDAMAGE
# 301267312    MNDAMAGE
# 301137549    MNDAMAGE
# 301743615    MNDAMAGE
# 301152672    MNDAMAGE
# Name: Code group, dtype: object

# %% [markdown]
# To access records efficiently pandas can construct an index for your data. Find out how you set the index on your dataframe and pick a useful column (i.e. one that has a unique value for each record and can be sorted) and set this as the index.
#
# Try selecting data using your index (especially if you have a timeseries index)

# %%
df.set_index('Notification')
# Out:
#              Notif.date  Notification Year Code group Damage Code  \
# Notification
# 301049381    2011-05-20               2011     MNWORK        CHCK
# 301116137    2011-12-01               2011     MNWORK        CHCK
# 301630883    2015-08-17               2015   SNSERSTD         NEW
# 300943307    2010-06-13               2010     MNWORK        CHCK
# 301079516    2011-08-16               2011     MNWORK        CHCK
# 301660103    2015-10-26               2015     MNWORK        UPGD
# 301403668    2014-03-11               2014        NaN         NaN
# 301468466    2014-08-18               2014     MNWORK        DISC
# 301297459    2013-05-23               2013   MNDAMAGE        BROK
# 301453151    2014-07-10               2014   MNDAMAGE        BROK
# 301506040    2014-11-07               2014   MNDAMAGE        BROK
# 301335630    2013-08-28               2013   MNDAMAGE        BROK
# 301267394    2013-02-28               2013   MNDAMAGE        BROK
# 301267796    2013-03-01               2013   MNDAMAGE        BROK
# 300927685    2010-04-23               2010   MNDAMAGE        BROK
# 301422743    2014-04-30               2014   MNDAMAGE        BROK
# 301443106    2014-06-17               2014   MNDAMAGE        BROK
# 301296680    2013-05-21               2013   MNDAMAGE        BROK
# 300914181    2010-03-02               2010   MNDAMAGE        BROK
# 300961980    2010-08-04               2010   MNDAMAGE        BROK
# 300993615    2010-11-02               2010   MNDAMAGE        BROK
# 301267312    2013-02-28               2013   MNDAMAGE        BROK
# 301137549    2012-02-10               2012   MNDAMAGE        BROK
# 301743615    2016-05-11               2016   MNDAMAGE        BROK
# 301152672    2012-04-02               2012   MNDAMAGE        BROK
# 301205630    2012-08-27               2012   MNDAMAGE        BROK
# 301206039    2012-08-28               2012   MNDAMAGE        BROK
# 301428224    2014-05-09               2014   MNDAMAGE        BROK
# 301221812    2012-10-09               2012   MNDAMAGE        BROK
# 301308672    2013-06-06               2013   MNDAMAGE        BROK
# ...                 ...                ...        ...         ...
# 301592546    2015-06-02               2015     MNWORK        ALTR
# 301227711    2012-10-31               2012     MNWORK        DISC
# 301396835    2014-02-24               2014     MNWORK        DEMO
# 300945182    2010-06-18               2010     MNWORK        DISC
# 301326311    2013-07-30               2013     MNWORK        DEMO
# 301139734    2012-02-21               2012     MNWORK        ALTR
# 301666047    2015-11-04               2015     MNWORK        ALTR
# 301150582    2012-03-26               2012     MNWORK        ALTR
# 301163460    2012-05-04               2012     MNWORK        ALTR
# 301168568    2012-05-18               2012     MNWORK        ALTR
# 301296389    2013-05-20               2013     MNWORK        ALTR
# 301359017    2013-10-30               2013     MNWORK        DEMO
# 301422808    2014-04-30               2014     MNWORK        DEMO
# 301519495    2014-12-08               2014     MNWORK        DISC
# 301583422    2015-05-08               2015     MNWORK        DISC
# 301609095    2015-06-30               2015     MNWORK        ALTR
# 301610217    2015-07-02               2015     MNWORK        DISC
# 301610418    2015-07-02               2015     MNWORK        DISC
# 301623386    2015-07-29               2015     MNWORK        DISC
# 301629154    2015-08-12               2015     MNWORK        ALTR
# 301629158    2015-08-12               2015     MNWORK        ALTR
# 301660093    2015-10-26               2015     MNWORK        DISC
# 301666495    2015-11-05               2015     MNWORK        ALTR
# 301709595    2016-02-17               2016     MNWORK        ALTR
# 301720563    2016-03-16               2016     MNWORK        ALTR
# 301727181    2016-03-31               2016     MNWORK        ALTR
# 301727484    2016-04-01               2016     MNWORK        ALTR
# 301731320    2016-04-12               2016     MNWORK        ALTR
# 301778180    2016-07-22               2016     MNWORK        ALTR
# 301788223    2016-08-08               2016     MNWORK        ALTR
#
#              Code group.1 Cause code Code group.2 ObjectPartCode  \
# Notification
# 301049381        MNREQUST       CUST     MNOBJECT           PIPE
# 301116137        MNREQUST       AGAS     MNOBJECT           PIPE
# 301630883             NaN        NaN     MNOBJECT           PIPE
# 300943307         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301079516        MNREQUST       CUST     MNOBJECT           PIPE
# 301660103        MNREQUST       ATCO     MNOBJECT           NOOB
# 301403668        MNREQUST       AGAS     MNOBJECT           PIPE
# 301468466        MNREQUST       AGAS     MNOBJECT           PIPE
# 301297459         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301453151         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301506040         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301335630         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301267394         MNCAUSE       ATCO     MNOBJECT           PIPE
# 301267796         MNCAUSE       ATCO     MNOBJECT           PIPE
# 300927685         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301422743         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301443106         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301296680         MNCAUSE       3PTY     MNOBJECT           PIPE
# 300914181         MNCAUSE       3PTY     MNOBJECT           PIPE
# 300961980         MNCAUSE       3PTY     MNOBJECT           PIPE
# 300993615         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301267312         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301137549         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301743615         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301152672         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301205630         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301206039         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301428224         MNCAUSE       3PTY     MNOBJECT           PIPE
# 301221812         MNCAUSE       ATCO     MNOBJECT           PIPE
# 301308672         MNCAUSE       3PTY     MNOBJECT           PIPE
# ...                   ...        ...          ...            ...
# 301592546        MNREQUST       CUST     MNOBJECT           PIPE
# 301227711        MNREQUST       CUST     MNOBJECT           PIPE
# 301396835        MNREQUST       CUST     MNOBJECT           PIPE
# 300945182             NaN        NaN     MNOBJECT           PIPE
# 301326311        MNREQUST       CUST     MNOBJECT           PIPE
# 301139734        MNREQUST       CUST     MNOBJECT           PIPE
# 301666047        MNREQUST       CUST     MNOBJECT           PIPE
# 301150582        MNREQUST       CUST     MNOBJECT           PIPE
# 301163460        MNREQUST       AGAS     MNOBJECT           PIPE
# 301168568        MNREQUST       AGAS     MNOBJECT           PIPE
# 301296389        MNREQUST       CUST     MNOBJECT           PIPE
# 301359017        MNREQUST       CUST     MNOBJECT           PIPE
# 301422808        MNREQUST       ATCO     MNOBJECT           PIPE
# 301519495        MNREQUST       CUST     MNOBJECT           PIPE
# 301583422        MNREQUST       CUST     MNOBJECT           PIPE
# 301609095        MNREQUST       CUST     MNOBJECT           PIPE
# 301610217        MNREQUST       CUST     MNOBJECT           PIPE
# 301610418        MNREQUST       CUST     MNOBJECT           PIPE
# 301623386        MNREQUST       CUST     MNOBJECT           PIPE
# 301629154        MNREQUST       CUST     MNOBJECT           PIPE
# 301629158        MNREQUST       CUST     MNOBJECT           PIPE
# 301660093        MNREQUST       CUST     MNOBJECT           PIPE
# 301666495        MNREQUST       ATCO     MNOBJECT           PIPE
# 301709595        MNREQUST       CUST     MNOBJECT           PIPE
# 301720563        MNREQUST       CUST     MNOBJECT           PIPE
# 301727181        MNREQUST       CUST     MNOBJECT           PIPE
# 301727484        MNREQUST       CUST     MNOBJECT           PIPE
# 301731320        MNREQUST       CUST     MNOBJECT           PIPE
# 301778180        MNREQUST       CUST     MNOBJECT           PIPE
# 301788223        MNREQUST       CUST     MNOBJECT           PIPE
#
#              Functional Loc.                               Description  \
# Notification
# 301049381           00900834           MN,HP,150,ST,CAPEL,RAILWAY,RD,2
# 301116137           00895059             MN,HP,50,ST,PNJRR,WANDOO,DR,2
# 301630883           01007110                 MN,HP,80,ST,BSNDN,SCADDAN
# 300943307           00876628    MN,MP,100,PVC,WNGRA,PARAMOUNT,DR,22,U1
# 301079516           00898718         MN,HP,225,PE,ALKMS,LEEWAY,LOOP,34
# 301660103           00000038                    PI,YNGBP,MIGUEL,RD,24;
# 301403668           00671433        MN,MLP,100,GI,WLGEE,WHEYLAND,ST,26
# 301468466           00876000              MN,LP,150,ST,E FTLE,SILAS ST
# 301297459           00450977     MN,AMP,80,PVC,SPNCR PRK,TASSELL,ST,5;
# 301453151           00450977     MN,AMP,80,PVC,SPNCR PRK,TASSELL,ST,5;
# 301506040           00453028       MN,AMP,50,PVC,MT CLRNC,THOMAS,ST,7;
# 301335630           00479319  MN,AMP,80,PVC,YAKAMIA,CHESTER PASS,RD,70
# 301267394           00504762      MN,AMP,80,PVC,MDDLTN BCH,HARE,ST,58;
# 301267796           00504762      MN,AMP,80,PVC,MDDLTN BCH,HARE,ST,58;
# 300927685           00520226      MN,AMP,63,PE,SPNCR PRK,HILLMAN,ST,93
# 301422743           00590344        MN,AMP,80,PVC,MT CLRNC,HARE,ST,123
# 301443106           00815528        MN,AMP,50,PVC,YAKAMIA,LESLIE,ST,19
# 301296680           00842107       MN,AMP,50,PVC,MRA MR,CHAMPION,ST,14
# 300914181           00869488    MN,AMP,100,PVC,SPNCR PRK,ANGOVE,RD,119
# 300961980           00880545       MN,AMP,100,PVC,YAKAMIA,TARGET,RD,60
# 300993615           00887402          MN,AMP,50,PVC,MRA MR,SHORTS,PL,8
# 301267312           00914516            MN,AMP,50,PVC,MRA MR,WAKEFIELD
# 301137549           00915914     MN,AMP,50,PVC,SPNCR PRK,BATELIER,CL,5
# 301743615           00917336      MN,AMP,50,PVC,MRA MR,BEAUCHAMP,ST,26
# 301152672           00918874     MN,AMP,100,PVC,SPNCR PRK,ANGOVE,RD,88
# 301205630           00927001       MN,AMP,50,PVC,YAKAMIA,LEONORA,ST,43
# 301206039           00927082       MN,AMP,80,PVC,MDDLTN BCH,HARE,ST,80
# 301428224           00928844           MN,AMP,100,PVC,LCKYR,CULL,RD,36
# 301221812           00929943     MN,AMP,50,PVC,SPNCR PRK,HILLMAN,ST,97
# 301308672           00931362                 MN,AMP,100,PVC,ALBNY,GREY
# ...                      ...                                       ...
# 301592546           00621790   MN,MLP,155,PVC,WHITE GM,STEVENS,ST,2089
# 301227711           00678586       MN,MP,155,PVC,SPRWD,HAMILTON,RD,301
# 301396835           00866777       MN,PEHP,160,PE,SCESS,CARNEGIE,PDE,1
# 300945182           00877140      MN,MP,63,PE,PIARA WTRS,WRIGHT,RD,369
# 301326311           00913324             MN,PEHP,160,PE,STHN RVR,,,403
# 301139734           00916504           MN,MP,63,PE,BYFD,BARJADDA,ST,17
# 301666047           00916903     MN,MP,155,PVC,ASCOT,TIBRADDEN,CIR,104
# 301150582           00918496   MN,NONE,40,PE,STHN RVR,BARNEVELDER,BEND
# 301163460           00920675       MN,MP,50,PVC,ARMDLE,TERRIGAL,WAY,12
# 301168568           00921599    MN,PEHP,160,PE,STHN RVR,BALFOUR,ST,457
# 301296389           00942848    MN,PEHP,40,PE,AUBIN GR,LATTERI,TURN,10
# 301359017           00954773           MN,MLP,100,PVC,CNGTN,KENT,ST,44
# 301422808           00961991        MN,PEHP,160,PE,JNDKT,KAREL,AVE,210
# 301519495           00985860                MN,MP,100,PVC,ASCOT,MARINA
# 301583422           00997903      MN,MP,110,PE,BNTLY,AUGUSTUS,WAY,1858
# 301609095           01002691                  MN,PEHP,40,PE,NTH COOGEE
# 301610217           01002963  MN,NONE,100,PVC,NTH COOGEE,GARSTON,WAY,1
# 301610418           01003045         MN,MP,110,PE,BYFD,MALARKEY,RD,135
# 301623386           01005444            MN,PEHP,40,PE,HARRISDALE,,,558
# 301629154           01006699   MN,PEHP,63,PE,AUBIN GR,SORBONNE,TURN,39
# 301629158           01006700      MN,PEHP,110,PE,AUBIN GR,BONDI,WAY,16
# 301660093           01013083          MN,PEHP,63,PE,HARRISDALE,DUNMORE
# 301666495           01014031     MN,MLP,100,PVC,WLTN,THE ESCARPMENT,,6
# 301709595           01021495           MN,PEHP,40,PE,NTH COOGEE,ORSINO
# 301720563           01026111                  MN,MP,63,PE,BLIAR,TINDAL
# 301727181           01027019               MN,MP,110,PE,STHN RVR,,,840
# 301727484           01027069                  MN,PEHP,40,PE,HARRISDALE
# 301731320           01027873                     MN,MP,110,PE,STHN RVR
# 301778180           01034552      MN,MP,110,PE,STHN RVR,FIGBIRD,WAY,46
# 301788223           01035708             MN,MP,100,PVC,RDCLF,REDCLIFFE
#
#                ...    Priority Priority Code  \
# Notification   ...
# 301049381      ...         NaN            SP
# 301116137      ...         NaN            SP
# 301630883      ...         NaN            SN
# 300943307      ...         NaN            SP
# 301079516      ...         NaN            SP
# 301660103      ...         NaN            SP
# 301403668      ...         NaN            SP
# 301468466      ...         NaN            SP
# 301297459      ...           1           SF1
# 301453151      ...           1           SF1
# 301506040      ...           1           SF1
# 301335630      ...           1           SF1
# 301267394      ...           1           SF1
# 301267796      ...           1           SF1
# 300927685      ...           1           SF1
# 301422743      ...           1           SF1
# 301443106      ...           1           SF1
# 301296680      ...           1           SF1
# 300914181      ...           1           SF1
# 300961980      ...           1           SF1
# 300993615      ...           1           SF1
# 301267312      ...           1           SF1
# 301137549      ...           1           SF1
# 301743615      ...           1           SF1
# 301152672      ...           1           SF1
# 301205630      ...           1           SF1
# 301206039      ...           1           SF1
# 301428224      ...           1           SF1
# 301221812      ...           1           SF1
# 301308672      ...           1           SF1
# ...            ...         ...           ...
# 301592546      ...           Z           SPZ
# 301227711      ...           Z           SPZ
# 301396835      ...           Z           SPZ
# 300945182      ...           Z           SPZ
# 301326311      ...           Z           SPZ
# 301139734      ...           Z           SPZ
# 301666047      ...           Z           SPZ
# 301150582      ...           Z           SPZ
# 301163460      ...           Z           SPZ
# 301168568      ...           Z           SPZ
# 301296389      ...           Z           SPZ
# 301359017      ...           Z           SPZ
# 301422808      ...           Z           SPZ
# 301519495      ...           Z           SPZ
# 301583422      ...           Z           SPZ
# 301609095      ...           Z           SPZ
# 301610217      ...           Z           SPZ
# 301610418      ...           Z           SPZ
# 301623386      ...           Z           SPZ
# 301629154      ...           Z           SPZ
# 301629158      ...           Z           SPZ
# 301660093      ...           Z           SPZ
# 301666495      ...           Z           SPZ
# 301709595      ...           Z           SPZ
# 301720563      ...           Z           SPZ
# 301727181      ...           Z           SPZ
# 301727484      ...           Z           SPZ
# 301731320      ...           Z           SPZ
# 301778180      ...           Z           SPZ
# 301788223      ...           Z           SPZ
#
#                                          Description.1     User status  \
# Notification
# 301049381                             PIP 89 DRILLSHOT       INI  NORD
# 301116137     PIP 18 Access Rights Mandurah Gas Latera             INI
# 301630883                          9 SLAB INSTALLATION             INI
# 300943307                       PIP ****SITE VISIT****       INI  NORD
# 301079516                           PIP 1016 EXCAVTION       INI  NORD
# 301660103           Install damage protection to HS005             INI
# 301403668           PIP Freo Cast Iron Stage 7; Area 4             INI
# 301468466                            DECOMMISSION MAIN             INI
# 301297459                                  BROKEN MAIN       INI  OBLD
# 301453151                                  BROKEN MAIN             INI
# 301506040                       M6WA324050 BROKEN MAIN       INI  OBLD
# 301335630                                  BROKEN MAIN            REIS
# 301267394          PIP BKN MAIN - PAT DURING (ATCOGAS)            REIS
# 301267796                              PIP BROKEN MAIN             INI
# 300927685               BROKEN MAIN - PETER 0437208804  INI  OBLD NORD
# 301422743                          BROKEN MAIN - 63 PE       INI  OBLD
# 301443106                                  BROKEN MAIN       INI  OBLD
# 301296680                                  BROKEN MAIN             INI
# 300914181                                  Broken Main  INI  OBLD NORD
# 300961980                              PIP broken main  INI  OBLD NORD
# 300993615              BRKN MAIN SUE MCNAMARA 98417343  INI  OBLD NORD
# 301267312                               BKN MAIN SIMON       REIS OBLD
# 301137549                              PIP BROKEN MAIN       INI  OBLD
# 301743615                            BROKEN MAIN OTHER        REIS TBB
# 301152672                               Brkn Main ATCO             INI
# 301205630                                  BROKEN MAIN             INI
# 301206039         BROKEN MAIN DAVE HASTIE 0417 742 402             INI
# 301428224                                  BROKEN MAIN             INI
# 301221812                                  BROKEN MAIN             INI
# 301308672                              PIP BROKEN MAIN            REIS
# ...                                                ...             ...
# 301592546                                  Cut and cap  INI  TBB  MMAN
# 301227711        PIP Cut AND Cap in DN150mm PVC 1.5 MP             INI
# 301396835                         PIP Cut and cap main       INI  OBLD
# 300945182                     PIP Cut AND Cap Gas Main  INI  OBLD NORD
# 301326311                         PIP Cut and cap main       INI  OBLD
# 301139734                 Permenantly Cut and Cap Main       INI  OBLD
# 301666047                                  cut and cap  INI  OBLD MMAN
# 301150582            Temporary Cut and Cap DN40mm PEHP       INI  OBLD
# 301163460                         PIP Abandon gas main             INI
# 301168568                      Cut and Cap DN40mm PEHP       INI  OBLD
# 301296389                              PIP Cut and Cap             INI
# 301359017                         PIP Cut and cap main       INI  OBLD
# 301422808                         PIP Cut and cap main       INI  MMAN
# 301519495                             CUT AND CAP MAIN  REIS OBLD MMAN
# 301583422                             CUT AND CAP MAIN  INI  OBLD MMAN
# 301609095                                  Cut and cap  INI  OBLD MMAN
# 301610217                                  CUT AND CAP  INI  OBLD MMAN
# 301610418                                  CUT AND CAP  INI  OBLD MMAN
# 301623386                                  CUT AND CAP  INI  OBLD MMAN
# 301629154               Cut and cap --> TEST N RELIGHT  INI  OBLD MMAN
# 301629158                                  cut and cap  INI  OBLD MMAN
# 301660093                 CUT AND CAP 1X DN20MM PE PLS  INI  OBLD MMAN
# 301666495     Cut and Cap, Relocate - UNDISC #4 - 5PM+       INI  MMAN
# 301709595                 CUT AND CAP DN40MM PEHP MAIN  INI  TBB  MMAN
# 301720563                                  cut and cap  INI  OBLD MMAN
# 301727181                                  cut and cap  REIS OBLD MMAN
# 301727484                                  cut and cap             INI
# 301731320                                  cut and cap       REIS MMAN
# 301778180                                  cut and cap  INI  OBLD MMAN
# 301788223                                  cut and cap  INI  TBB  MMAN
#
#                     System status         Cause code text              City  \
# Notification
# 301049381               NOCO NOPT        Customer Request             CAPEL
# 301116137               NOCO ORAS             AGN Request          PINJARRA
# 301630883                    OSNO                     NaN        BASSENDEAN
# 300943307               ATCO NOCO  3rd Party Intervention           WANGARA
# 301079516               NOCO NOPT        Customer Request           ALKIMOS
# 301660103               NOPR ORAS            ATCO Request          YANGEBUP
# 301403668               NOCO ORAS             AGN Request          WILLAGEE
# 301468466                    NOCO             AGN Request    EAST FREMANTLE
# 301297459          ATCO NOCO ORAS  3rd Party Intervention      SPENCER PARK
# 301453151     ATCO NOCO NOPT ORAS  3rd Party Intervention      SPENCER PARK
# 301506040     ATCO NOCO NOPT ORAS  3rd Party Intervention    MOUNT CLARENCE
# 301335630     ATCO NOCO NOPT ORAS  3rd Party Intervention           YAKAMIA
# 301267394     ATCO NOCO NOPT ORAS           ATCO Operator   MIDDLETON BEACH
# 301267796     ATCO NOCO NOPT ORAS           ATCO Operator   MIDDLETON BEACH
# 300927685          ATCO NOCO NOPT  3rd Party Intervention      SPENCER PARK
# 301422743     ATCO NOCO NOPT ORAS  3rd Party Intervention    MOUNT CLARENCE
# 301443106     ATCO NOCO NOPT ORAS  3rd Party Intervention           YAKAMIA
# 301296680     ATCO NOCO NOPT ORAS  3rd Party Intervention          MIRA MAR
# 300914181          ATCO NOCO NOPT  3rd Party Intervention      SPENCER PARK
# 300961980     ATCO NOCO NOPT ORAS  3rd Party Intervention           YAKAMIA
# 300993615          ATCO NOCO NOPT  3rd Party Intervention          MIRA MAR
# 301267312     ATCO NOCO NOPT ORAS  3rd Party Intervention          MIRA MAR
# 301137549     ATCO NOCO NOPT ORAS  3rd Party Intervention      SPENCER PARK
# 301743615     ATCO NOCO NOPT ORAS  3rd Party Intervention          MIRA MAR
# 301152672     ATCO NOCO NOPT ORAS  3rd Party Intervention      SPENCER PARK
# 301205630     ATCO NOCO NOPT ORAS  3rd Party Intervention           YAKAMIA
# 301206039     ATCO NOCO NOPT ORAS  3rd Party Intervention   MIDDLETON BEACH
# 301428224     ATCO NOCO NOPT ORAS  3rd Party Intervention           LOCKYER
# 301221812          ATCO NOCO ORAS           ATCO Operator      SPENCER PARK
# 301308672     ATCO NOCO NOPT ORAS  3rd Party Intervention            ALBANY
# ...                           ...                     ...               ...
# 301592546     ATCO NOCO NOPT ORAS        Customer Request  WHITE GUM VALLEY
# 301227711     ATCO NOCO NOPT ORAS        Customer Request         SPEARWOOD
# 301396835     ATCO NOCO NOPT ORAS        Customer Request           SUCCESS
# 300945182          ATCO NOCO NOPT                     NaN      PIARA WATERS
# 301326311     ATCO NOCO NOPT ORAS        Customer Request    SOUTHERN RIVER
# 301139734     ATCO NOCO NOPT ORAS        Customer Request            BYFORD
# 301666047          ATCO NOCO ORAS        Customer Request             ASCOT
# 301150582     ATCO NOCO NOPT ORAS        Customer Request    SOUTHERN RIVER
# 301163460     ATCO NOCO NOPT ORAS             AGN Request          ARMADALE
# 301168568     ATCO NOCO NOPT ORAS             AGN Request    SOUTHERN RIVER
# 301296389     ATCO NOCO NOPT ORAS        Customer Request       AUBIN GROVE
# 301359017     ATCO NOCO NOPT ORAS        Customer Request        CANNINGTON
# 301422808          ATCO NOCO ORAS            ATCO Request          JANDAKOT
# 301519495     ATCO NOCO NOPT ORAS        Customer Request             ASCOT
# 301583422          ATCO NOCO ORAS        Customer Request           BENTLEY
# 301609095          ATCO NOCO ORAS        Customer Request      NORTH COOGEE
# 301610217          ATCO NOCO ORAS        Customer Request      NORTH COOGEE
# 301610418          ATCO NOCO ORAS        Customer Request            BYFORD
# 301623386          ATCO NOCO ORAS        Customer Request        HARRISDALE
# 301629154     ATCO NOPR NOPT ORAS        Customer Request       AUBIN GROVE
# 301629158          ATCO NOCO ORAS        Customer Request       AUBIN GROVE
# 301660093          ATCO NOCO ORAS        Customer Request        HARRISDALE
# 301666495          ATCO NOCO ORAS            ATCO Request         WILLETTON
# 301709595     NOPR NOPT ORAS OSTS        Customer Request      NORTH COOGEE
# 301720563          ATCO NOCO ORAS        Customer Request           BEELIAR
# 301727181          ATCO NOCO ORAS        Customer Request    SOUTHERN RIVER
# 301727484               NOCO ORAS        Customer Request        HARRISDALE
# 301731320     NOPR NOPT ORAS OSTS        Customer Request    SOUTHERN RIVER
# 301778180          NOPR ORAS OSTS        Customer Request    SOUTHERN RIVER
# 301788223     NOPR NOPT ORAS OSTS        Customer Request         REDCLIFFE
#
#              Malfunct. start Malfunct.end Location
# Notification
# 301049381         2011-05-20   2011-05-24       BS
# 301116137         2011-12-01          NaT       MA
# 301630883         2015-08-17          NaT       NM
# 300943307         2010-06-07   2010-06-08       NM
# 301079516         2011-08-17   2011-08-17       NM
# 301660103         2015-10-26          NaT       SM
# 301403668         2014-03-11          NaT       SM
# 301468466         2014-08-18          NaT       SM
# 301297459         2013-05-23   2013-05-23       AL
# 301453151         2014-07-10   2014-07-10       AL
# 301506040         2014-11-07   2014-11-07       AL
# 301335630         2013-08-28   2013-08-28       AL
# 301267394         2013-02-28   2013-02-28       AL
# 301267796         2013-03-01   2013-03-01       AL
# 300927685         2010-04-23   2010-04-23       AL
# 301422743         2014-04-30   2014-04-30       AL
# 301443106         2014-06-17   2014-06-17       AL
# 301296680         2013-05-21   2013-05-21       AL
# 300914181         2010-03-02   2010-03-02       AL
# 300961980         2010-08-04   2010-08-04       AL
# 300993615         2010-11-02   2010-11-02       AL
# 301267312         2013-02-28   2013-02-28       AL
# 301137549         2012-02-10   2012-02-10       AL
# 301743615         2016-05-11   2016-05-11       AL
# 301152672         2012-04-02   2012-04-02       AL
# 301205630         2012-08-27   2012-08-27       AL
# 301206039         2012-08-28   2012-08-28       AL
# 301428224         2014-05-09   2014-05-09       AL
# 301221812         2012-10-09   2012-10-09       AL
# 301308672         2013-06-06   2013-06-06       AL
# ...                      ...          ...      ...
# 301592546         2015-06-02   2015-06-15       SM
# 301227711         2012-10-31   2012-11-12       SM
# 301396835         2014-02-24   2014-02-27       SM
# 300945182         2010-06-18   2010-06-22       SM
# 301326311         2013-07-30   2013-08-24       SM
# 301139734         2012-02-21   2012-03-08       SM
# 301666047         2015-11-04   2015-11-09       SM
# 301150582         2012-03-26   2012-06-18       SM
# 301163460         2012-05-04   2012-05-30       SM
# 301168568         2012-05-18   2012-06-19       SM
# 301296389         2013-05-20   2013-05-23       SM
# 301359017         2013-10-30   2013-11-19       SM
# 301422808         2014-04-30   2014-05-07       SM
# 301519495         2014-12-08   2015-02-11       SM
# 301583422         2015-05-11   2015-05-11       SM
# 301609095         2015-06-30   2015-07-21       SM
# 301610217         2015-07-02   2015-07-17       SM
# 301610418         2015-07-02   2015-07-03       SM
# 301623386         2015-07-29   2015-08-11       SM
# 301629154         2015-08-12   2015-08-19       SM
# 301629158         2015-08-12   2015-08-20       SM
# 301660093         2015-10-26   2015-12-01       SM
# 301666495         2015-11-05   2015-11-12       SM
# 301709595         2016-02-17          NaT       SM
# 301720563         2016-03-16   2016-04-07       SM
# 301727181         2016-03-31   2016-04-19       SM
# 301727484         2016-04-01          NaT       SM
# 301731320         2016-04-12   2016-05-12       SM
# 301778180         2016-07-22   2016-07-28       SM
# 301788223         2016-08-08          NaT       SM
#
# [23021 rows x 30 columns]

# %%
df.loc[0:5]
# Out:
#    Notification Notif.date  Notification Year Code group Damage Code  \
# 0     301049381 2011-05-20               2011     MNWORK        CHCK
# 1     301116137 2011-12-01               2011     MNWORK        CHCK
# 2     301630883 2015-08-17               2015   SNSERSTD         NEW
# 3     300943307 2010-06-13               2010     MNWORK        CHCK
# 4     301079516 2011-08-16               2011     MNWORK        CHCK
# 5     301660103 2015-10-26               2015     MNWORK        UPGD
#
#   Code group.1 Cause code Code group.2 ObjectPartCode Functional Loc.  \
# 0     MNREQUST       CUST     MNOBJECT           PIPE        00900834
# 1     MNREQUST       AGAS     MNOBJECT           PIPE        00895059
# 2          NaN        NaN     MNOBJECT           PIPE        01007110
# 3      MNCAUSE       3PTY     MNOBJECT           PIPE        00876628
# 4     MNREQUST       CUST     MNOBJECT           PIPE        00898718
# 5     MNREQUST       ATCO     MNOBJECT           NOOB        00000038
#
#     ...    Priority Priority Code                             Description.1  \
# 0   ...         NaN            SP                          PIP 89 DRILLSHOT
# 1   ...         NaN            SP  PIP 18 Access Rights Mandurah Gas Latera
# 2   ...         NaN            SN                       9 SLAB INSTALLATION
# 3   ...         NaN            SP                    PIP ****SITE VISIT****
# 4   ...         NaN            SP                        PIP 1016 EXCAVTION
# 5   ...         NaN            SP        Install damage protection to HS005
#
#   User status System status         Cause code text        City  \
# 0   INI  NORD     NOCO NOPT        Customer Request       CAPEL
# 1         INI     NOCO ORAS             AGN Request    PINJARRA
# 2         INI          OSNO                     NaN  BASSENDEAN
# 3   INI  NORD     ATCO NOCO  3rd Party Intervention     WANGARA
# 4   INI  NORD     NOCO NOPT        Customer Request     ALKIMOS
# 5         INI     NOPR ORAS            ATCO Request    YANGEBUP
#
#   Malfunct. start Malfunct.end Location
# 0      2011-05-20   2011-05-24       BS
# 1      2011-12-01          NaT       MA
# 2      2015-08-17          NaT       NM
# 3      2010-06-07   2010-06-08       NM
# 4      2011-08-17   2011-08-17       NM
# 5      2015-10-26          NaT       SM
#
# [6 rows x 31 columns]

# %% [markdown]
# If you get through this quickly, take a look at the [other data formats that pandas is able to read](http://pandas.pydata.org/pandas-docs/stable/api.html#input-output) and find out about these online - we can have a discussion about when you might like to use them. Pay particular attention to [`pandas.read_sql`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql.html#pandas.read_sql) as that's pretty useful for ripping data from databases.
#
# Go to [data.gov.au](https://data.gov.au) and find some other data in different formats to read and try reading it.
#
# ## Step 2: What's in my data?
#
# First find the documentation in pandas on datatypes!
#
# Work through the columns in your dataset and assign them to the correct datatype.

# %%
df['Code group'].dropna().unique()
# Out:
# array(['MNWORK', 'SNSERSTD', 'MNDAMAGE', 'SVDAMAGE', 'MDDAMAGE',
#        'RSDAMAGE', 'SVWORK', 'MDWORK', 'GSWORK'], dtype=object)

# %%
df.dtypes
# Out:
# Notification                  int64
# Notif.date           datetime64[ns]
# Notification Year             int64
# Code group                   object
# Damage Code                  object
# Code group.1                 object
# Cause code                   object
# Code group.2                 object
# ObjectPartCode               object
# Functional Loc.              object
# Description                  object
# Type                         object
# Pressure Rating              object
# Pipe Size                    object
# Pipe Material                object
# Suburb                       object
# Street Name                  object
# Street Type                  object
# Street No.                   object
# Notifictn type               object
# PriorityType                 object
# Priority                     object
# Priority Code                object
# Description.1                object
# User status                  object
# System status                object
# Cause code text              object
# City                         object
# Malfunct. start      datetime64[ns]
# Malfunct.end         datetime64[ns]
# Location                     object
# dtype: object

# %%
df['Pipe Size'].unique()
# Out:
# array([150, 50, 80, 100, 225, 'MIGUEL', 63, 110, 200, 195, 155, 40, 160,
#        'BUSSELL', 0, 'MARINA QUAY', 300, 'WOLLASTON', 250, 'NEVILLE',
#        'SUMMERS', 'BONNER', 'MONASH', 230, 330, 'BERNLEY', 90, 350, 325,
#        'KIRKHAM HILL', 180, 'MARMION', 'SHEFFIELD', 'BLANCOA', 175, 426,
#        75, 32, 'SUNBURY', 'BOYANUP-PICTON', 'WILLOW', 'HERDSMAN',
#        'BOLLACH', 'FAIRWAY', 'WINDEMERE', 'HORRIE MILLER', 'RAILWAY',
#        'HAMMAD', 380, 'TURNER', 'HOLLOSY', nan, 'BURDHAM', 'ADMIRAL',
#        'KAMPONG', 'NELSON', 'MIDDLETON', 'FESTING', 'ROBERTSON',
#        'RAWLING', 'SALISBURY', 'COTTESLOE', 'MUSTIQUE', 'SIXTY EIGHT',
#        'BURTENSHAW', 'MARKALING', 'TOULOUSE', 'ROYAL', 'GEORGE', 'TREEN',
#        'MILES', 'BOURKE', 'CHARLES', 'DRISCOLL', 'DICKSON', 'HEADINGLY',
#        'WEST COAST', 'STAPLES', 'STIRLING', 635, 'LUMSDEN', 'ROCCA',
#        'VIEW', 'RANGE VIEW', 'CRAWFORD', 'OFFHAM', 'MILL POINT', 'MOORE',
#        'ROSSMOYNE', 'SEVENTH', 'BIRCH', 'TROODE', 'LEACH', 'CHALLIS', 25,
#        'JENEVER', 'STALKER', 'REDWOOD', 'JULIET', 'MCLACHLAN', 'LYONS',
#        'OVENS', 'KENNEDY', 'SHEPPERTON', 'SYDENHAM', 'ROBERTS', 240,
#        'LION', 'MCLARTY', 'LEEUWIN', 'AMAZON', 'OAKMONT', 'WILLOUGHBY',
#        'MINCHIN', 'HOPETOUN', 'LORD', 'RUDALL', 'WATERSIDE', 'ROSEBERY',
#        'WILLIAM', 'KINGSWAY', 'FORTESCUE', 'FOSS', 'WELD', 'GERARD',
#        'OLNEY', 20, 'MAWSON', 'ARMANTA', 'FORREST', 'GLOUCESTER',
#        'CROFTER', 'REDCLIFFE', 'SPENCER', 'MAKYBE', 'RIDGE', 'GARRATT',
#        'CAROLYN', 'ALDERSEA', 'JONES', 'ANDERSON', 'HOWLETT', 'NICHOLSON',
#        'HENSMAN', 'MINORA', 'SHAFTESBURY', 'BENARA', 'JAMES', 'CLAYTON',
#        'PALMERSTON', 'CALEDONIAN', 'HAGART', 'SCOTT', 'ONSLOW',
#        'GREAT EASTERN', 'NORTH BEACH', 'HAYWARD', 'MONTROSE',
#        'GREAT NORTHERN', 'NORBURY', 280, 'PEDERICK', 'METZ', 'CANOVA',
#        'CASSINO', 'WOLSELEY', 'BELLAZARIO', 'GLYDE', 'RESERVE', 'FARRIN',
#        'WARRAGOON', 'TODD', 'BUZZA', 'BRIDGE', 'PALLAS', 'PARK',
#        'BARDWELL', 'SLEE', 'FOSTER', 'BEDFORDALE HILL', 'HOLLAND',
#        'PILGRIM', 'HARPER', 'NANNINE', 'GAY', 'BELLBIRD', 'ABERNETHY',
#        'MANNING', 'CURTIS', 'BOUNDARY', 'CROSS', 'HOGARTH', 'BROOKTON',
#        'EVELYN', 'HAY', 'SOUTHGATE', 'GEDDES', 'WELLINGTON', 'BARRACK',
#        'KENSINGTON', 'BEACH', 'OAKLEY', 'SAFETY BAY', 'PLANET',
#        'CASUARINA', 'NEWCASTLE', 'TERRACE', 'LITTLE SHENTON', 'HAVELOCK',
#        'PARKER', 'ABERDEEN', 'THE ESPLANADE', 'ADELAIDE', 'JOHN',
#        'MURRAY', 'FRANCIS', 'PENZANCE', 'HOPE', 'MORRIT', 'READ',
#        'SECRET HARBOUR', 'RICHARDSON', 'CHISHAM', 'SULPHUR', 'BRISTOW',
#        'LANYON', 'CHILCOTT', 'DUFFY', 'BUSINESS', 'DUNDAS', 'WANNEROO',
#        'FLINDERS', 'CRAIGIE', 'CELESTINE', 'MARDA', 'BRADFORD',
#        'MILLIGAN', 'DAWSON', 'HELLENIC', 'MAIDA VALE', 'ABBEY', 'NEAVES',
#        'MELLER', 'ANGUS', 'MURDOCH', 'WILLERI', 'LESLIE', 'TATE',
#        'MATISON', 'AMELIA', 'HOLFORD', 'VIVIAN', 'WEAPONESS', 'BURT',
#        'SOUTH', 'PAYNE', 'LEATH', 'BROWN', 'YORK', 'NORTH LAKE'],
#       dtype=object)

# %%
2.isnumeric()
# Out:
#   File "<ipython-input-78-662840d977a7>", line 1
#     2.isnumeric()
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# How will you find incorrect values in your data? Can you write a small function to test these? For more details on Python functions you can work through [this little tutorial on DataCamp](https://www.datacamp.com/community/tutorials/functions-python-tutorial)
#
# Also take a look at the [`apply`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.apply.html) method for more tricky data munging that has to be carried out record-by-record
#
# Try writing a small function to apply to one of the columns in your dataframe - here's a toy example to get you started: your function could look something like:
#
# ```python
# import random
# import pandas
#
# # Make some bogus data - see random_data.py for defns
# from random_data import random_dataframe
#
# df = random_dataframe(10)
#
# # Define our bogus function
# def random_replacement(record):
#     "Some of column 'a', some of column 'b'"
#     return random.sample([record.a, record.b], 1)[0]
#
# # Apply function once per record
# df.apply(random_replacement, axis='columns')
# ```
#
# Work out how to apply a function once per column as well.

# %% [markdown]
# ### Step 3: Tidy my data
#
# Work through the 'tidy data checklist' and make sure your data has been tidied!
#
# 1. Each variable you measure should be in one column.
# 2. Each different observation of that variable should be in a different row.
# 3. There should be one table for each "kind" of variable.
# 4. If you have multiple tables, they should include a column in the table that allows them to be linked.
#
# This is a good overview: http://www.jeannicholashould.com/tidy-data-in-python.html
#
# If your data is already tidy, try downloading the data from that tutorial and working through it instead.

# %% [markdown]
# Once you're done with this, copy your code from steps 2 and 3 over to a Python script for easier sharing. This is an example of an extract-transform-load workflow that you could share with your IT department to run automatically when your org collects more data that is similar to this.
